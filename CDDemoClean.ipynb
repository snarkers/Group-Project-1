# %%
import pandas as pd
import os
import glob

# %%
path = os.path.join("CDDemoCleanCSVs", "05Demographic.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    Year                 Districts  Estimate; Total:  \
# 0  2005  Congressional District 1          664756.0
# 1  2005  Congressional District 2          685115.0
# 2  2005  Congressional District 3          793790.0
# 3  2005  Congressional District 4          709717.0
# 4  2005  Congressional District 5          669399.0
#
#    Estimate; Not Hispanic or Latino:  \
# 0                           586811.0
# 1                           575260.0
# 2                           628674.0
# 3                           633937.0
# 4                           554305.0
#
#    Estimate; Not Hispanic or Latino: - White alone  \
# 0                                         456662.0
# 1                                         405872.0
# 2                                         440910.0
# 3                                         540849.0
# 4                                         453144.0
#
#    Estimate; Not Hispanic or Latino: - Black or African American alone  \
# ...

# %%
path = r'C:\Users\danie\OneDrive\Desktop\bootcamp\Group-Project-1\CDDemoCleanCSVs'
all_files = glob.glob(os.path.join(path, "*.csv"))

df_from_each_file = (pd.read_csv(f) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file, ignore_index = True)
concatenated_df.head()
# Out:
# C:\Users\danie\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#                   Districts  Estimate; Hispanic or Latino:  \
# 0  Congressional District 1                        77945.0
# 1  Congressional District 2                       109855.0
# 2  Congressional District 3                       165116.0
# 3  Congressional District 4                        75780.0
# 4  Congressional District 5                       115094.0
#
#    Estimate; Hispanic or Latino: - American Indian and Alaska Native alone  \
# 0                                              101.0
# 1                                              581.0
# 2                                              530.0
# ...

# %%
concatenated_df.to_csv("TotalDemographics.csv")
